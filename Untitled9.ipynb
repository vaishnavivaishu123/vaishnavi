# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('D:/AIML/Cars93.csv')
df
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.hist(df['MPG.city'])
ax.set_title('histogram to check frequency of mpg')
ax.set_ylabel("miles per gallon",fontsize=12)
ax.set_xlabel("frequency")
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6176\2171930238.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.boxplot(df['Price'])
ax.set_title('Price range of all different cars')
ax.set_ylabel("miles per gallon",fontsize=12)
ax.set_xlabel("price",fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6176\2669078156.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.scatter(df["Horsepower"],df["MPG.city"])
ax.set_title("To determine whether a car with higer horsepower gives lower milage")
ax.set_ylabel("Horsepower",fontsize=12)
ax.set_xlabel("MPG",fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6176\3741794806.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=["Horsepower"])
line_df=line_df.mean()
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
plt.plot(df['Horsepower'],df['EngineSize'],label='EngineSize')
ax.set_title("variation in EngineSize")
ax.set_ylabel("EngineSize",fontsize=12)
ax.set_xlabel("Horsepower",fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6176\2782359435.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
